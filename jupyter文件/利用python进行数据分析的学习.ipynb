# %%
import pandas as pd
import numpy as np
#一个数组就可以创建简单的series
obj = pd.Series([2,4,6,7,9,-2,4],index=['a','b','c','d','e','f','g'])
# obj.array
# obj.index
# obj*2
# '2' in obj
stata = {"first":20,"second":30,"third":90}
stata1 = ['second','third','c']
# obj2 = pd.Series(stata)
obj2 = pd.Series(stata,index=stata1)
# obj2.to_dict()
# pd.notna(obj2)
# obj2.isna()
obj2.name = '哈哈'
obj2.index.name= '不笑'
obj2
# Out:
# 不笑
# second    30.0
# third     90.0
# c          NaN
# Name: 哈哈, dtype: float64

# %%
import pandas as pd
import numpy as np
data = {"State":['ofio','ofio','ofio','ofio','ofio','ofio'],
        "year":[2001,2002,2003,2004,2005,2006],
        "pop":[1.4,1.5,1.6,1.2,1.3,1.9]
        }
# columns指定列的序列
frame = pd.DataFrame(data,columns=['year','pop','State','w'])
frame.tail()
# frame['year']
# frame.loc
frame['w']= 11   #通过赋值的方式修改列
frame[2] = frame['year'] > 2005   # 可以通过赋值的方式来新增列
# del frame['w']    #通过del来删除列
frame
# 如果遇到嵌套的字典，dateframe会把最外层做列，内层字典的键做为行索引、
# frame.T
frame.index.name='w'
frame = frame.to_numpy()
# print(type(frame))
# Out:
# array([[2001, 1.4, 'ofio', 11, False],
#        [2002, 1.5, 'ofio', 11, False],
#        [2003, 1.6, 'ofio', 11, False],
#        [2004, 1.2, 'ofio', 11, False],
#        [2005, 1.3, 'ofio', 11, False],
#        [2006, 1.9, 'ofio', 11, True]], dtype=object)

# %%
import pandas as pd
import numpy as np
# obj = pd.Series(np.arange(3),index= ['a','b','c'])
# index = obj.index
# # index[1]
# labels = pd.Index(np.arange(3))
# obj = obj.reindex(['a','b','c','d','e'])
# # obj1 = obj.reindex(np.arange(6),method='ffill')
# obj
data = pd.DataFrame(np.arange(16).reshape((4,4)),index = ['a','b','c','d'],columns=[1,2,3,4])
data
# data.drop(index = ['a','d'])
# data.drop(columns=[2,4])
# data.drop(2,axis='columns')
# obj1 = pd.Series([3,1,2],index=['a','b','c'])
# obj12 = pd.Series([3,1,2],index=[1,2,3])

# obj12.iloc[[0,1,2]]
# Out:
#    1  2  3  4
# a  0  1  2  3
# b  4  5  6  7
